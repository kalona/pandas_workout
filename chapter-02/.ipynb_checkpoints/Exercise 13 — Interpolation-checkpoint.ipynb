# %%
# %pylab inline
import pandas as pd
from pandas import Series, DataFrame

s = pd.read_csv('data/nyc-temps.txt', squeeze=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = Series([10, 20, 30, 40, 50, NaN, 70])

# %%
s.size
# Out:
# 7

# %%
s.count()
# Out:
# 6

# %%
df = DataFrame({'a':range(7), 's':s})

# %%
df
# Out:
#    a     s
# 0  0  10.0
# 1  1  20.0
# 2  2  30.0
# 3  3  40.0
# 4  4  50.0
# 5  5   NaN
# 6  6  70.0

# %%
df.size
# Out:
# 14

# %%
df.count()
# Out:
# a    7
# s    6
# dtype: int64
